# %%
my_array = [
    {
        "source_container_name":"olympics",
        "source_folder":"raw",
        "source_folder_directory":"nocs",
        "target_folder":"bronze",
        "target_folder_directory":"nocs"
    },
    {
        "source_container_name":"olympics",
        "source_folder":"raw",
        "source_folder_directory":"coaches",
        "target_folder":"bronze",
        "target_folder_directory":"coaches"
    },
    {
        "source_container_name":"olympics",
        "source_folder":"raw",
        "source_folder_directory":"events",
        "target_folder":"bronze",
        "target_folder_directory":"events"
    },
    {
        "source_container_name":"olympics",
        "source_folder":"raw",
        "source_folder_directory":"athletes",
        "target_folder":"bronze",
        "target_folder_directory":"athletes"
    }

]

# %%
dbutils.jobs.taskValues.set(key = "my_output", value = my_array)
